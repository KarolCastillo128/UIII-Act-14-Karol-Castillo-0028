# %% [markdown]
# <a href="https://colab.research.google.com/github/KarolCastillo128/UIII-Act-14-Karol-Castillo-0028/blob/main/UIII_Act_14_Karol_Castillo_0028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Karol Castillo NL = 9 Fecha 27/mayo/2026 2-H
# #### CBTis 128
# #### Inteligencia Artificial
# #### Elabora Proyectos con Programacion Logica
# #### Docente : ING. Eliseo Nava
#
#
# # Problema 9:
# # Escribe un programa que dados dos números, uno real (base) y un entero positivo (exponente), saque por pantalla el resultado de la potencia. No se puede utilizar el operador de potencia.

# %%
# Solicitar datos al usuario
base = float(input("Introduce la base: "))
exponente = int(input("Introduce el exponente (entero positivo): "))

# Calcular la potencia sin usar **
resultado = 1

for i in range(exponente):
    resultado *= base

# Mostrar resultado
print("El resultado es:", resultado)
# Out:
# Introduce la base: 6
# Introduce el exponente (entero positivo): 2
# El resultado es: 36.0

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/KarolCastillo128/UIII-Act-14-Karol-Castillo-0028/refs/heads/main/IAAA.png)
